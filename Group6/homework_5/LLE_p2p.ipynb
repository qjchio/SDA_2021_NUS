# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn import manifold, datasets
import seaborn as sns

# %%
#load data
data = pd.read_csv('d:\WFH\others\FE5225\codes\LLE-master\LLE_p2p\p2p.csv', index_col=0)

# %%
#Get status data and delete status and nace column from the dataframe
y = data.status
data = data.drop(['status', 'nace'], axis=1)

# %%
#Dimentionality reduction using LLE to the P2P data, with neighbors set to 15 and number of components set to 2
X_r, err = manifold.locally_linear_embedding(data, n_neighbors=15,
                                             n_components=2, random_state=0) #returns embedding vector and reconstruction error

LLEresult = pd.DataFrame(X_r)
LLEresult['y'] = y

# %%
#Apply colors to status 1 (red) and 0 (blue)
def colors(row):
    if row==True:
        return 'red'
    else:
        return 'blue'
colors = y.apply(colors)

# %%
#Plot the figure of LLE outcome
fig = plt.figure(figsize=(10, 10))
plt.scatter(X_r[colors=='blue',0], X_r[colors=='blue',1], marker='o', c='blue')
plt.scatter(X_r[colors=='red',0], X_r[colors=='red',1], marker='o', c='red')
plt.ylim((-0.06, 0.06))
plt.xlim((-0.04, 0.06))
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.title('Reduced to 2D using LLE')
plt.savefig('./LLE_reduce.png', transparent=True)

# %%
#reverse the layer sequence of previous figure
fig = plt.figure(figsize=(10, 10))
plt.scatter(X_r[colors=='red',0], X_r[colors=='red',1], marker='o', c='red')
plt.scatter(X_r[colors=='blue',0], X_r[colors=='blue',1], marker='o', c='blue')
plt.ylim((-0.06, 0.06))
plt.xlim((-0.04, 0.06))
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.title('Reduced to 2D using LLE')
plt.savefig('./LLE_reduce2.png', transparent=True)

# %%
#Dimentionality reduction using LLE with neighbors equal to 15 and number of coordinates to 10
X_r2, err2 = manifold.locally_linear_embedding(data, n_neighbors=15,
                                             n_components=10, random_state=0)

LLEresult2 = pd.DataFrame(X_r2)
LLEresult2['y'] = y

# %%
#Plot the results
sns_plot = sns.pairplot(LLEresult2, hue="y")
sns_plot.savefig("p2p_LLE_n_components10.png")
